# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = np.arange(0,1000,1)
I=np.cos(w/10)*(1+(w-1/w)**2)
plt.plot(w,I)
plt.show()
# Out:
# C:\Users\Grant\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %% [markdown]
# The Current is at an extremum whenever $\omega t = \frac{n*\pi}{2}$ where $n \in \mathbb{N}$
